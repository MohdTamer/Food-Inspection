# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/Business_Licenses.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24380\3112413904.py:1: DtypeWarning: Columns (9,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/Business_Licenses.csv')

# %%
df['LICENSE TERM START DATE'] = pd.to_datetime(df['LICENSE TERM START DATE'], errors='coerce')
print(df['LICENSE TERM START DATE'].isnull().sum())
print(len(df))
# Out:
# 2718
# 1194013
